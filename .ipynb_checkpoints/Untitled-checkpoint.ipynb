# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('crime_analysis.csv')

data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 195        11         0        1         8        10        1      1

# %%
data.sort_values('murder', ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 133                          San Jose State University      60472       2
# 164                              University of Arizona      39236       1
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 183                  University of Illinois at Chicago      84273       1
# 0                               American River College      95250       0
# 155                 The University of Texas at El Paso      22640       0
# 145                    Tarrant County College District     300372       0
# 146                                  Temple University     294840       0
# 147             Texas A & M University-College Station     100460       0
# 148                  Texas State University-San Marcos      68174       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 133             0         3         0        2        13        24       13
# ...

# %%
data.sort_values('forcible', ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 166                  University of California-Berkeley      72274       0
# 107                  Ohio State University-Main Campus      56867       0
# 167                     University of California-Davis      63464       0
# 213                    University of Wisconsin-Madison      41946       0
# 116          Pennsylvania State University-Main Campus      45628       0
# 65                                  Harvard University      54784       0
# 1                             Arizona State University     289016       0
# 56                        George Washington University     202080       0
# 91                           Michigan State University     191300       0
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 166             0        30         1        9         7        40       14
# ...

# %%
data.sort_values('forcible', ascending=False)[:30]
# Out:
#                                               instname  total_enr  murder  \
# 166                  University of California-Berkeley      72274       0
# 107                  Ohio State University-Main Campus      56867       0
# 167                     University of California-Davis      63464       0
# 213                    University of Wisconsin-Madison      41946       0
# 116          Pennsylvania State University-Main Campus      45628       0
# 65                                  Harvard University      54784       0
# 1                             Arizona State University     289016       0
# 56                        George Washington University     202080       0
# 91                           Michigan State University     191300       0
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 193                   University of Michigan-Ann Arbor      42716       0
# 211                 University of Virginia-Main Campus     145782       0
# ...

# %%
data["total_count"] = data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]

data[:5]
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 0             American River College      95250       0             0
# 1           Arizona State University     289016       0             0
# 2                 Ashford University      74596       0             0
# 3                  Auburn University      25469       0             0
# 4  Austin Community College District    1082400       0             0
#
#    forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 0         1         2        3         2         6        8      0
# 1        17         1       11        27        90       17     11
# 2         2         0        0         0         1        0      0
# 3         1         0        2         0        22        3      0
# 4         0         0        0         1         2        0      0
#
#    total_count
# 0           22
# 1          174
# 2            3
# 3           28
# 4            3

# %%
data["total_count"] = (data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"])

data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
data["total_count"] = data["total_enr"] / (data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"])

data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d6f4666627f4> in <module>()
# ----> 1 data[(data.total_enr >= 10000) & (data.total_count < 5)].sort_index('total_count')
#
# /Users/Marshall/.virtualenvs/dataj/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, by)
#    3662                                     inplace=inplace)
#    3663
# -> 3664         axis = self._get_axis_number(axis)
#    3665         labels = self._get_axis(axis)
#    3666
#
# /Users/Marshall/.virtualenvs/dataj/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# --> 357                          .format(axis, type(self)))
#     358
# ...

# %%
data["total_count"] = (data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]) / data["total_enr"]

data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
data[(data.total_enr >= 10000) & (data.total_count < 5)].sort_values('total_count')
# Out:
#                                               instname  total_enr  murder  \
# 77                  Kaplan University-Davenport Campus      56606       0
# 122                                 Rio Salado College     251090       0
# 16                                  Capella University      36375       0
# 220                                  Walden University      48982       0
# 143                   Suffolk County Community College     107148       0
# 47                                   Excelsior College      35608       0
# 38                           DeVry University-Illinois     279210       0
# 157                        Thomas Edison State College      20251       0
# 4                    Austin Community College District    1082400       0
# 190          University of Maryland-University College     256278       0
# 27                    Columbus State Community College     247368       0
# 37                   Des Moines Area Community College     279675       0
# ...

# %%
data["total_count"] = data["forcible"] + data["nonforce"]
data.sort_values("total_count")
data
# Out:
#                                               instname  total_enr  murder  \
# 0                               American River College      95250       0
# 1                             Arizona State University     289016       0
# 2                                   Ashford University      74596       0
# 3                                    Auburn University      25469       0
# 4                    Austin Community College District    1082400       0
# 5                                Ball State University      44294       0
# 6                                    Boston University      64878       0
# 7                       Brigham Young University-Provo     170505       0
# 8                                      Broward College     379782       0
# 9       California State Polytechnic University-Pomona      21107       0
# 10                  California State University-Fresno      21981       0
# 11               California State University-Fullerton     144624       0
# ...

# %%
# Story Idea:
# 1. Schools with the highest crimes per capita
#    1. University of South Carolina-Columbia 0.004752
#    2. University of North Carolina at Charlotte 0.003284
#    3. University of New Mexico-Main Campus 0.003175
#    4. University of Utah 0.003095
#    5. California State University-Fresno 0.002593
# 2. Schools with no crimes reported, despite their size.
# 3. Highest number of sexual assaults (forcible and nonforce) 
#    1. University of Wisconsin-Madison 24
#    2. Arizona State University 18
#    3. Virginia Polytechnic Institute and State University 14
#    4. University of Washington-Seattle Campus 13
#    5. University of Oklahoma Norman Campus 13
